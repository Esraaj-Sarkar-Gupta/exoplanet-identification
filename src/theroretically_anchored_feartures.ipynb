# %%
"""
theoretically_anchored_features.ipynb

Engineering physics aware features.
    - Transit Depth Consistency
    - Duration Consistency
    - Impact Parameter Squared Consistency

Author: Esraaj Sarkar Gupta
"""
# Out:
# '\ntheoretically_anchored_features.ipynb\n\nEngineering physics aware features.\n    - Transit Depth Consistency\n    - Duration Consistency\n    - Impact Parameter Squared Consistency\n\nAuthor: Esraaj Sarkar Gupta\n'

# %%
# ---- Imports ---- #
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# --- Physical Constants (SI Units) --- #
G_CONST = 6.6743e-11      # Gravitational constant in m^3 / (kg * s^2)
R_SUN = 6.957e8           # Radius of the Sun in meters
M_SUN = 1.9884e30         # Mass of the Sun in kilograms
AU_UNIT = 1.496e11        # Meters to Astronomical Units
R_EARTH = 6.371e6         # Radius of the Earth in meters
HOURS_PER_DAY = 24        # Number of hours in a day

# ---- Load Data ---- #
data_path : Path = Path("../data/physics/derived_params_features_KOI.csv")

df = pd.read_csv(data_path)

df.head()
# Out:
#    Unnamed: 0     kepid koi_disposition  koi_period  koi_duration  koi_depth  \
# 0           0   5980783       CONFIRMED   37.303320        7.7930      551.7
# 1           1  10212441       CONFIRMED   15.044710        5.8230       97.9
# 2           2   8395660       CONFIRMED   43.844397        6.8020      615.2
# 3           3   8478994       CONFIRMED   21.301819        3.8763       87.3
# 4           4   4833421       CONFIRMED   37.996237        6.7751      403.7
#
#    koi_model_snr  koi_prad  koi_teq  koi_insol  koi_steff  koi_slogg  \
# 0           19.5      2.31    493.0      14.00     5646.0      4.550
# 1           23.4      1.51    931.0     177.24     5798.0      4.025
# 2           83.7      2.87    531.0      18.77     5854.0      4.406
# 3           32.4      0.72    564.0      23.89     5437.0      4.571
# 4           37.8      2.39    618.0      34.55     6038.0      4.284
#
#    koi_srad  phys_smass  phys_sma  Target
# 0     0.817    0.863731  0.208074     1.0
# ...

# %%
# ---- Depth Anchoring ---- #

# Earth to Sun radius conversion constant
R_earth_to_sun = 0.009158

# Compute theoretical depth (ppm)
df['theo_depth'] = ((df['koi_prad'] * R_earth_to_sun) / df['koi_srad'])**2 * 1e6

# Compute residue
df['phys_depth_residual'] = (df['koi_depth'] - df['theo_depth']).abs()

# View
display(df.head())
# Out:
#    Unnamed: 0     kepid koi_disposition  koi_period  koi_duration  koi_depth  \
# 0           0   5980783       CONFIRMED   37.303320        7.7930      551.7
# 1           1  10212441       CONFIRMED   15.044710        5.8230       97.9
# 2           2   8395660       CONFIRMED   43.844397        6.8020      615.2
# 3           3   8478994       CONFIRMED   21.301819        3.8763       87.3
# 4           4   4833421       CONFIRMED   37.996237        6.7751      403.7
#
#    koi_model_snr  koi_prad  koi_teq  koi_insol  koi_steff  koi_slogg  \
# 0           19.5      2.31    493.0      14.00     5646.0      4.550
# 1           23.4      1.51    931.0     177.24     5798.0      4.025
# 2           83.7      2.87    531.0      18.77     5854.0      4.406
# 3           32.4      0.72    564.0      23.89     5437.0      4.571
# 4           37.8      2.39    618.0      34.55     6038.0      4.284
#
#    koi_srad  phys_smass  phys_sma  Target  theo_depth  phys_depth_residual
# ...

# %%
# -- Visualize Depth Anchoring -- #
plt.figure()
plt.scatter(df["phys_depth_residual"], df["Target"], c=df["Target"].map({0: "red", 1: "green"}))

plt.xlabel("phys_depth_residual")
plt.ylabel("Target")

plt.grid(True)
plt.show()

R = np.corrcoef(
    df["phys_depth_residual"],
    df["Target"]
)

print(R)
# Out:
# [[ 1.         -0.04302179]
#  [-0.04302179  1.        ]]

# %%
# ---- Duration Consistency Anchoring ---- #
# Reliant on a zero eccentricity assumption

# Unit conversion ratio
Rstar_by_AU_ratio = R_SUN / AU_UNIT

# Theoretical Anchor
df["theo_duration"] = (2 * df["koi_srad"] * df["koi_period"]) / (2 * np.pi * df["phys_sma"]) * Rstar_by_AU_ratio

# Compute residue
df["phys_duration_residual"] = (df["koi_duration"] - df["theo_duration"]).abs()

# View
display(df.head())
# Out:
#    Unnamed: 0     kepid koi_disposition  koi_period  koi_duration  koi_depth  \
# 0           0   5980783       CONFIRMED   37.303320        7.7930      551.7
# 1           1  10212441       CONFIRMED   15.044710        5.8230       97.9
# 2           2   8395660       CONFIRMED   43.844397        6.8020      615.2
# 3           3   8478994       CONFIRMED   21.301819        3.8763       87.3
# 4           4   4833421       CONFIRMED   37.996237        6.7751      403.7
#
#    koi_model_snr  koi_prad  koi_teq  koi_insol  koi_steff  koi_slogg  \
# 0           19.5      2.31    493.0      14.00     5646.0      4.550
# 1           23.4      1.51    931.0     177.24     5798.0      4.025
# 2           83.7      2.87    531.0      18.77     5854.0      4.406
# 3           32.4      0.72    564.0      23.89     5437.0      4.571
# 4           37.8      2.39    618.0      34.55     6038.0      4.284
#
#    koi_srad  phys_smass  phys_sma  Target  theo_depth  phys_depth_residual  \
# ...

# %%
# -- Visualise Duration Residue -- #
plt.figure()
plt.scatter(df["phys_duration_residual"], df["Target"], c=df["Target"].map({0: "red", 1: "green"}))

plt.xlabel("phys_duration_residual")
plt.ylabel("Target")

plt.grid(True)
plt.show()

R = np.corrcoef(
    df["phys_duration_residual"],
    df["Target"]
)

print(R)
# Out:
# [[ 1.         -0.18817927]
#  [-0.18817927  1.        ]]

# %%
# ---- Impact Parameter Anchoring ---- #
# Reliant on a zero eccentricity assumption

# Unit Conversion Ratios
AU_by_Rstar_ratio = AU_UNIT / R_SUN
Rearth_by_Rstar_ratio = R_EARTH / R_SUN

# Radius Ratio
df["theo_radius_ratio"] = df["koi_prad"] / df["koi_srad"] * Rearth_by_Rstar_ratio 

# Distance Ratio
df["theo_distance_ratio"] = df["phys_sma"] / df["koi_srad"] * AU_by_Rstar_ratio

# Compute impact parameter
df["phys_impact_parameter_squared"] = (1 + df["theo_radius_ratio"])**2 - \
    (df["koi_duration"] * np.pi * df["theo_distance_ratio"] / (df["koi_period"] * HOURS_PER_DAY))**2

display(df.head())
# Out:
#    Unnamed: 0     kepid koi_disposition  koi_period  koi_duration  koi_depth  \
# 0           0   5980783       CONFIRMED   37.303320        7.7930      551.7
# 1           1  10212441       CONFIRMED   15.044710        5.8230       97.9
# 2           2   8395660       CONFIRMED   43.844397        6.8020      615.2
# 3           3   8478994       CONFIRMED   21.301819        3.8763       87.3
# 4           4   4833421       CONFIRMED   37.996237        6.7751      403.7
#
#    koi_model_snr  koi_prad  koi_teq  koi_insol  ...  phys_smass  phys_sma  \
# 0           19.5      2.31    493.0      14.00  ...    0.863731  0.208074
# 1           23.4      1.51    931.0     177.24  ...    0.898409  0.115082
# 2           83.7      2.87    531.0      18.77  ...    0.951252  0.239314
# 3           32.4      0.72    564.0      23.89  ...    0.828393  0.141238
# 4           37.8      2.39    618.0      34.55  ...    0.994851  0.220804
#
# ...

# %%
# -- Visualise Impact Parameter Squared -- #
plt.figure()
plt.scatter(df["phys_impact_parameter_squared"], df["Target"], c=df["Target"].map({0: "brown", 1: "green"}))

plt.xlabel("phys_impact_parameter_squared")
plt.ylabel("Target")

plt.grid(True)
plt.show()

R = np.corrcoef(
    df["phys_impact_parameter_squared"],
    df["Target"]
)

print(R)
# Out:
# [[1.         0.06136346]
#  [0.06136346 1.        ]]

# %%
# ---- Stephan Boltzman Anchoring ---- #
# Assuming an Albedo of 0.3
# Assuming earth's equillibrium temperature is 255K

EARTH_TEQ = 255     # K

df["phys_thermal"] = (df["koi_insol"] / (df["koi_teq"] / 255)**4)
df["phys_thermal_residual"] = 1 - df["phys_thermal"]
display(df.head())
# Out:
#    Unnamed: 0     kepid koi_disposition  koi_period  koi_duration  koi_depth  \
# 0           0   5980783       CONFIRMED   37.303320        7.7930      551.7
# 1           1  10212441       CONFIRMED   15.044710        5.8230       97.9
# 2           2   8395660       CONFIRMED   43.844397        6.8020      615.2
# 3           3   8478994       CONFIRMED   21.301819        3.8763       87.3
# 4           4   4833421       CONFIRMED   37.996237        6.7751      403.7
#
#    koi_model_snr  koi_prad  koi_teq  koi_insol  ...  Target  theo_depth  \
# 0           19.5      2.31    493.0      14.00  ...     1.0  670.472740
# 1           23.4      1.51    931.0     177.24  ...     1.0   82.227197
# 2           83.7      2.87    531.0      18.77  ...     1.0  674.534313
# 3           32.4      0.72    564.0      23.89  ...     1.0   71.279428
# 4           37.8      2.39    618.0      34.55  ...     1.0  337.733046
#
#    phys_depth_residual  theo_duration  phys_duration_residual  \
# ...

# %%
# -- Visualise Thermal Anchor -- #
plt.figure()
plt.scatter(df["phys_thermal_residual"], df["Target"], c=df["Target"].map({0: "crimson", 1: "green"}))

plt.xlabel("phys_thermal_residual")
plt.ylabel("Target")

plt.grid(True)
plt.show()

R = np.corrcoef(
    df["phys_impact_parameter_squared"],
    df["Target"]
)

print(R)
# Out:
# [[1.         0.06136346]
#  [0.06136346 1.        ]]

# %%
# ---- Save Dataframe into CSV ---- #
_SAVE_PATHNAME = Path("../data/koi/physics_train/physically_anchored_features_KOI.csv")

# Reorder csv
cols = [col for col in df.columns if col != "Target"] + ["Target"]
data = df[cols]

display(data.head())
data.to_csv(_SAVE_PATHNAME)
# Out:
#    Unnamed: 0     kepid koi_disposition  koi_period  koi_duration  koi_depth  \
# 0           0   5980783       CONFIRMED   37.303320        7.7930      551.7
# 1           1  10212441       CONFIRMED   15.044710        5.8230       97.9
# 2           2   8395660       CONFIRMED   43.844397        6.8020      615.2
# 3           3   8478994       CONFIRMED   21.301819        3.8763       87.3
# 4           4   4833421       CONFIRMED   37.996237        6.7751      403.7
#
#    koi_model_snr  koi_prad  koi_teq  koi_insol  ...  theo_depth  \
# 0           19.5      2.31    493.0      14.00  ...  670.472740
# 1           23.4      1.51    931.0     177.24  ...   82.227197
# 2           83.7      2.87    531.0      18.77  ...  674.534313
# 3           32.4      0.72    564.0      23.89  ...   71.279428
# 4           37.8      2.39    618.0      34.55  ...  337.733046
#
#    phys_depth_residual  theo_duration  phys_duration_residual  \
# ...
